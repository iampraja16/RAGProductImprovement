# %% [markdown]
# # 5. Graph to SQL Sync
#
# Notebook ini berfungsi untuk menyinkronkan (sync) hasil deteksi komunitas *Leiden* dari Neo4j kembali ke dalam PostgreSQL.
# Proses ini akan memastikan Vanna SQL memiliki kolom `graph_community_summary` yang berisi rangkuman masalah per EMR.

# %%
import os
import sys

# Add root project directory to path
sys.path.append(os.path.abspath('..'))

from scripts.sync_graph_to_sql import main as run_sync

print("Memulai proses sinkronisasi dari Neo4j ke PostgreSQL...")
run_sync()
print("\nSinkronisasi selesai!")
# Out:
# INFO:scripts.sync_graph_to_sql:=== Starting bidirectional sync ===
# INFO:src.graph.client:Connected to Neo4j at bolt://localhost:7687
# INFO:scripts.sync_graph_to_sql:Fetching community mappings from Neo4j...
# Memulai proses sinkronisasi dari Neo4j ke PostgreSQL...
# INFO:scripts.sync_graph_to_sql:Retrieved 7464 EMR community mappings
# INFO:scripts.sync_graph_to_sql:Synced 7464 community_ids to PostgreSQL
# INFO:scripts.sync_graph_to_sql:Fetching display columns from PostgreSQL...
# INFO:scripts.sync_graph_to_sql:Retrieved 28094 records from PostgreSQL
# INFO:scripts.sync_graph_to_sql:  Progress: 500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 1000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 1500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 2000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 2500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 3000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 3500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 4000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 4500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 5000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 5500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 6000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 6500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 7000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 7500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 8000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 8500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 9000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 9500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 10000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 10500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 11000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 11500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 12000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 12500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 13000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 13500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 14000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 14500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 15000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 15500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 16000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 16500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 17000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 17500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 18000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 18500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 19000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 19500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 20000/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 20500/20629
# INFO:scripts.sync_graph_to_sql:  Progress: 20629/20629
# INFO:scripts.sync_graph_to_sql:Synced 20629 EMRRecord nodes with display columns
# INFO:scripts.sync_graph_to_sql:=== Sync complete ===
# Sinkronisasi selesai!
